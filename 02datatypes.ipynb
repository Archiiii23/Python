# %%
a = 1 # a is an integer
b = 5.55 # b is an floating point number
c = "Archii" # c is a string
d = False # d is a boolean variable
e = None # e is a none type variable
