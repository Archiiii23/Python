# %%
m=int (input("ENTER THE NUMBER:" ))
if(m%3==0 and m%5!=0):
    print("NUMBER IS FIZZZZ")
elif(m%5==0 and m%3!=0):
    print("NUMBER IS BUZZZZ")
elif(m%3==0 and m%5==0):
    print("NUMBER IS BOTH FIZZZ AND BUZZZZ")
else:
    print("NONE!!!")
# Out:
# NUMBER IS BOTH FIZZZ AND BUZZZZ
