# %%
m=int (input("ENTER THE MARKS:" ))
if m>=90:
    print("GRADE A")
elif m>=80:
    print("GRADE B")
elif m>=70:
    print("GRADE C")
elif m>=60:
    print("GRADE D")
else:
    print("GRADE E")
# Out:
# GRADE A
